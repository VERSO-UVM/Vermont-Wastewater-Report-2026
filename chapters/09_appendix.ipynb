# %% [markdown]
# # Appendix
#
# This appendix provides supplementary information, data sources, technical notes, and references to support the main chapters of this report.

# %% [markdown]
# ## A. Data Sources and Datasets
#
# ### Primary Data Sources
#
# 1. **Vermont Department of Environmental Conservation (DEC)**
#    - Wastewater facility database
#    - NPDES permit data
#    - Discharge monitoring reports (DMR)
#
# 2. **U.S. Environmental Protection Agency (EPA)**
#    - ECHO (Enforcement and Compliance History Online)
#    - Facility Registry Service (FRS)
#    - Safe Drinking Water Information System (SDWIS)
#
# 3. **U.S. Geological Survey (USGS)**
#    - National Hydrography Dataset (NHD)
#    - Water quality monitoring data
#    - StreamStats
#
# 4. **Vermont Center for Geographic Information (VCGI)**
#    - Vermont GIS data portal
#    - Watershed boundaries
#    - Land use and land cover data

# %% [markdown]
# ## B. Technical Methodology
#
# ### GIS Analysis Methods
#
# - **Coordinate Reference System**: Vermont State Plane (EPSG:32145)
# - **Buffer Analysis**: Various buffer distances for proximity analysis
# - **Spatial Join**: Point-in-polygon analysis for facility-watershed assignment
# - **Network Analysis**: Flow path analysis in watershed networks

# %% [markdown]
# ### Statistical Methods
#
# - Descriptive statistics
# - Trend analysis
# - Correlation analysis
# - Time series analysis

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Set up visualization defaults
plt.style.use('seaborn-v0_8-darkgrid')
# %matplotlib inline

# %% [markdown]
# ## C. Glossary of Terms
#
# **BOD (Biochemical Oxygen Demand)**: A measure of the amount of oxygen required by bacteria to break down organic matter in water.
#
# **NPDES (National Pollutant Discharge Elimination System)**: A permit program that regulates point source discharges to waters of the United States.
#
# **Phosphorus (P)**: A nutrient that can cause excessive algae growth when present in high concentrations in water bodies.
#
# **TMDL (Total Maximum Daily Load)**: A calculation of the maximum amount of a pollutant that a water body can receive while still meeting water quality standards.
#
# **TSS (Total Suspended Solids)**: The amount of solid particles suspended in water.
#
# **WWTF (Wastewater Treatment Facility)**: A facility designed to treat domestic and/or industrial wastewater.

# %% [markdown]
# ## D. Acronyms and Abbreviations
#
# - **CWA** - Clean Water Act
# - **DEC** - Department of Environmental Conservation
# - **EPA** - Environmental Protection Agency
# - **GIS** - Geographic Information System
# - **MGD** - Million Gallons per Day
# - **NPDES** - National Pollutant Discharge Elimination System
# - **POTW** - Publicly Owned Treatment Works
# - **TMDL** - Total Maximum Daily Load
# - **USGS** - United States Geological Survey
# - **VCGI** - Vermont Center for Geographic Information
# - **WWTF** - Wastewater Treatment Facility

# %% [markdown]
# ## E. References
#
# ### Key Reports and Documents
#
# 1. Vermont Department of Environmental Conservation. (2024). *Vermont Water Quality Standards*.
#
# 2. Lake Champlain Basin Program. (2023). *Opportunities for Action: An Evolving Plan for the Future of the Lake Champlain Basin*.
#
# 3. U.S. EPA. (2015). *Lake Champlain Phosphorus TMDL*.
#
# 4. Vermont Department of Environmental Conservation. (2023). *Vermont Wastewater System and Potable Water Supply Rules*.
#
# ### Scientific Literature
#
# (Additional references would be added here as the research develops)

# %% [markdown]
# ## F. Data Tables
#
# ### Table F.1: Vermont Wastewater Treatment Facilities Summary
#
# (Summary tables of facility data would be included here)

# %%
# Example: Display summary statistics
# facilities = pd.read_csv('../data/facilities.csv')
# facilities.describe()

# %% [markdown]
# ## G. Contact Information
#
# For questions or additional information about this report:
#
# **Vermont Department of Environmental Conservation**
# Watershed Management Division
# 1 National Life Drive, Davis 3
# Montpelier, VT 05620-3522
#
# **Project Team**
# Vermont Wastewater Analysis Team
# Email: [contact information to be added]

# %% [markdown]
# ## H. Supplementary Maps and Figures
#
# Additional maps and visualizations that support the main chapters.

# %% [markdown]
# ## I. Data Access and Reproducibility
#
# All data and code used in this analysis are available in the project repository. To reproduce this analysis:
#
# 1. Clone the repository
# 2. Install required dependencies
# 3. Access data files in the `data/` directory
# 4. Run Jupyter notebooks in sequence
